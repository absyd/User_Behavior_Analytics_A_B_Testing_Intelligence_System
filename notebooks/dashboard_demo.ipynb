# %% [markdown]
# # 🎯 User Behavior Analytics Dashboard
#
# ## 📊 Interactive Streamlit Dashboard
#
# This notebook demonstrates how to launch and interact with the comprehensive User Behavior Analytics Dashboard.
#
# ### 🚀 Dashboard Features:
#
# **📈 Overview & Summary**
# - Key metrics (avg purchase, customers, revenue)
# - Revenue by category analysis
# - Customer demographics (age, income distribution)
#
# **📊 Distribution Analysis**
# - Interactive histograms and box plots
# - Statistical measures (mean, median, std, skewness, kurtosis)
# - Normality testing (Shapiro-Wilk, Kolmogorov-Smirnov)
#
# **📉 Statistical Metrics**
# - Correlation analysis (Pearson, Spearman, Kendall)
# - Confidence interval calculations
# - Interactive scatter plots with trendlines
#
# **🎯 A/B Testing**
# - Discount impact analysis
# - Loyalty program effectiveness
# - Custom A/B test setup
# - Statistical significance testing
# - Effect size calculations
#
# **🔍 Outlier Detection**
# - Multiple detection methods (IQR, Z-score, Modified Z-score)
# - Interactive outlier visualization
# - Detailed outlier analysis
#
# **👥 Customer Segmentation**
# - K-means clustering analysis
# - Silhouette score evaluation
# - Interactive segment visualization
# - Cluster statistics
#
# **📱 Feature Analysis**
# - Feature importance ranking
# - Correlation matrix heatmap
# - Strong correlation identification
#
# ---

# %% [markdown]
# ## 🚀 Launching the Dashboard
#
# ### Method 1: Direct Launch (Recommended)
#
# Run this command in your terminal from the project root directory:

# %%
# Launch the dashboard using Python script
# !python run_dashboard.py

# %% [markdown]
# ### Method 2: Manual Streamlit Launch
#
# Alternatively, you can launch Streamlit directly:

# %%
# Navigate to dashboard directory and launch
import os
os.chdir('dashboard')
# !streamlit run app.py --server.port 8501

# %% [markdown]
# ### 📱 Access Information
#
# Once launched, the dashboard will be available at:
# - **Local URL**: http://localhost:8501
# - **Network URL**: http://your-local-ip:8501
#
# The dashboard will automatically open in your default browser.
#
# ---

# %% [markdown]
# ## 📖 Usage Guide
#
# ### 🎛️ Navigation
#
# Use the sidebar to navigate between different analysis pages:
#
# 1. **📈 Overview & Summary** - Quick insights and key metrics
# 2. **📊 Distribution Analysis** - Deep dive into data distributions
# 3. **📉 Statistical Metrics** - Correlations and confidence intervals
# 4. **🎯 A/B Testing** - Hypothesis testing and experiment analysis
# 5. **🔍 Outlier Detection** - Identify and analyze outliers
# 6. **👥 Customer Segmentation** - Cluster analysis and customer groups
# 7. **📱 Feature Analysis** - Feature importance and correlations
#
# ### 🎛️ Interactive Controls
#
# Each page includes:
# - **Dropdown menus** for variable selection
# - **Sliders** for parameter adjustment
# - **Buttons** for analysis execution
# - **Interactive charts** with zoom and hover capabilities
#
# ### 📊 Data Overview
#
# The sidebar always shows:
# - Total records in dataset
# - Number of unique customers
# - Total revenue
# - Current analysis status
#
# ---

# %% [markdown]
# ## 💡 Example Analyses
#
# ### 🎯 A/B Testing Example
#
# **Question**: Do discounts increase purchase amounts?
#
# **Steps**:
# 1. Navigate to "🎯 A/B Testing"
# 2. Select "Discount Impact"
# 3. Review the statistical results
# 4. Check the confidence intervals
# 5. Analyze the effect size
#
# ### 🔍 Outlier Detection Example
#
# **Question**: Are there unusual purchase amounts in the data?
#
# **Steps**:
# 1. Navigate to "🔍 Outlier Detection"
# 2. Select "Purchase_Amount_Float"
# 3. Choose detection method (IQR recommended)
# 4. Review outlier statistics
# 5. Examine the visualization
#
# ### 👥 Customer Segmentation Example
#
# **Question**: Can we identify distinct customer groups?
#
# **Steps**:
# 1. Navigate to "👥 Customer Segmentation"
# 2. Select features: Age, Purchase_Amount_Float, Frequency_of_Purchase
# 3. Set number of clusters to 4
# 4. Review silhouette score (should be > 0.5)
# 5. Analyze cluster statistics
#
# ---

# %% [markdown]
# ## 🔧 Troubleshooting
#
# ### Common Issues:
#
# **❌ ModuleNotFoundError**
# ```bash
# pip install -r requirements.txt
# ```
#
# **❌ Data loading error**
# - Ensure `Ecommerce_Consumer_Behavior_Analysis_Data_fixed.csv` is in the `data/` folder
# - Check file permissions
#
# **❌ Port already in use**
# ```bash
# streamlit run app.py --server.port 8502
# ```
#
# **❌ Dashboard not loading**
# - Check internet connection
# - Try refreshing the browser
# - Restart the dashboard
#
# ### 📞 Getting Help
#
# If you encounter issues:
# 1. Check the terminal output for error messages
# 2. Verify all dependencies are installed
# 3. Ensure data files are in correct locations
# 4. Try restarting the dashboard
#
# ---

# %% [markdown]
# ## 🎉 Conclusion
#
# The User Behavior Analytics Dashboard provides a comprehensive, interactive platform for:
#
# ✅ **Exploratory Data Analysis** - Understand your data distributions and patterns
# ✅ **Statistical Testing** - Conduct rigorous A/B tests and hypothesis testing
# ✅ **Customer Insights** - Segment customers and identify behavior patterns
# ✅ **Outlier Detection** - Identify and analyze unusual data points
# ✅ **Feature Analysis** - Discover important variables and relationships
#
# ### 🚀 Next Steps:
#
# 1. **Explore the Data**: Start with the Overview page to understand key metrics
# 2. **Run A/B Tests**: Test your hypotheses about customer behavior
# 3. **Segment Customers**: Identify distinct customer groups for targeting
# 4. **Detect Anomalies**: Find outliers that might indicate fraud or opportunities
# 5. **Export Insights**: Use the findings to inform business decisions
#
# ### 📈 Business Value:
#
# - **Data-Driven Decisions**: Make decisions based on statistical evidence
# - **Customer Understanding**: Deep insights into customer behavior
# - **Experimentation**: Rigorous testing of marketing strategies
# - **Anomaly Detection**: Identify issues and opportunities quickly
# - **Segmentation**: Target specific customer groups effectively
#
# ---
#
# **🎯 Ready to start analyzing? Launch the dashboard and explore your data!**
